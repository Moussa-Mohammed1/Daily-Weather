# %%
import pandas as pd 

df =  pd.read_csv("../data/bronze/cities/ma.csv")
print(df.head())
# Out:
#          city      lat     lng  country iso2                 admin_name  \
# 0  Casablanca  33.5992 -7.6200  Morocco   MA          Casablanca-Settat
# 1     Tangier  35.7767 -5.8039  Morocco   MA  Tanger-Tétouan-Al Hoceïma
# 2         Fès  34.0433 -5.0033  Morocco   MA                 Fès-Meknès
# 3   Marrakech  31.6295 -7.9811  Morocco   MA             Marrakech-Safi
# 4        Sale  34.0500 -6.8167  Morocco   MA         Rabat-Salé-Kénitra
#
#   capital  population  population_proper
# 0   admin     3950000            3215935
# 1   admin     1275428            1275428
# 2   admin     1167842            1167842
# 3   admin     1085330            1002697
# 4     NaN      945101             945101

# %%
print(df.tail())
# Out:
#                   city      lat      lng  country iso2  \
# 116        Oulad Yaïch  32.4167  -6.3333  Morocco   MA
# 117  Zawyat ech Cheïkh  32.6541  -5.9214  Morocco   MA
# 118       Imi-n-Tanout  31.1770  -8.8504  Morocco   MA
# 119        Sebt Gzoula  32.1219  -9.0889  Morocco   MA
# 120           Tifariti  26.1580 -10.5670  Morocco   MA
#
#                   admin_name  capital  population  population_proper
# 116     Béni Mellal-Khénifra      NaN       25785              25785
# 117     Béni Mellal-Khénifra      NaN       25088              25088
# 118           Marrakech-Safi      NaN       25049              25049
# 119           Marrakech-Safi      NaN       24600              24600
# 120  Laâyoune-Sakia El Hamra  primary        3000               3000

# %%
print(df.describe())
# Out:
#               lat         lng    population  population_proper
# count  121.000000  121.000000  1.210000e+02       1.210000e+02
# mean    32.718407   -6.857740  1.763869e+05       1.695289e+05
# std      2.139883    2.408091  4.083458e+05       3.519383e+05
# min     23.716700  -15.950000  3.000000e+03       3.000000e+03
# 25%     31.570000   -8.429200  4.028300e+04       4.028300e+04
# 50%     33.197800   -6.700000  7.613400e+04       7.613400e+04
# 75%     34.176600   -5.532800  1.315420e+05       1.315420e+05
# max     35.841400   -1.911400  3.950000e+06       3.215935e+06

# %%
print(df.shape)
# Out:
# (121, 9)

# %%
print(df.isna().sum())
# Out:
# city                   0
# lat                    0
# lng                    0
# country                0
# iso2                   0
# admin_name             0
# capital              110
# population             0
# population_proper      0
# dtype: int64

# %%
print(df.columns)
# Out:
# Index(['city', 'lat', 'lng', 'country', 'iso2', 'admin_name', 'capital',
#        'population', 'population_proper'],
#       dtype='str')

# %%
print(df.dtypes)
# Out:
# city                     str
# lat                  float64
# lng                  float64
# country                  str
# iso2                     str
# admin_name               str
# capital                  str
# population             int64
# population_proper      int64
# dtype: object

# %% [markdown]
# ### check duplicated

# %%
print(df.duplicated().sum())
print(df[df.duplicated()])
# Out:
# 1
#     city      lat     lng  country iso2      admin_name capital  population  \
# 12  Safi  32.2833 -9.2333  Morocco   MA  Marrakech-Safi     NaN      367249
#
#     population_proper
# 12             367249

# %%
required_columns =  [
    "lng", "lat", "city"
]
print(df[required_columns].head())
# Out:
#       lng      lat        city
# 0 -7.6200  33.5992  Casablanca
# 1 -5.8039  35.7767     Tangier
# 2 -5.0033  34.0433         Fès
# 3 -7.9811  31.6295   Marrakech
# 4 -6.8167  34.0500        Sale

# %%
import matplotlib.pyplot as plt

plt.scatter(df["lat"], df["lng"])
plt.xlabel("Longitude")
plt.ylabel("Latitude")
plt.title("Moroccan cities")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
